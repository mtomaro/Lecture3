# %% [markdown]
# ## Tuples:
# The tuple object is roughly like a list that cannot be changed. Tuples are immutable.

# %%
# A 4-item tuple
T = (1 , 2 , 3 , 4)

# %%
# Length
len(T)
# Out:
# 4

# %%
#Concatenate
T + (5,6)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#indexing, slicing, and more
T[0]
# Out:
# 1

# %%
#Tuples are immutable 
T[0]=2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-6aa19097e1e7> in <module>()
#       1 #Tuples are immutable
# ----> 2 T[0]=2
#
# TypeError: 'tuple' object does not support item assignment

# %%
#make a new tuple for a new value with the old name
T = (2,) + T[1:]
# need to put comma otheriwse it will think its an integer and a tuple so it doesnt know what to do with + sign

# %%
T = 'spam', 3.0, [11,22,33]
# no paranthesis will default as a tuple

# %%
T[1]
# Out:
# 3.0

# %%
T[2][1]
# Out:
# 22

# %%
#can't append a tuple since it is immutable
T.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-57cba2398e3f> in <module>()
#       1 #can't append a tuple since it is immutable
# ----> 2 T.append(4)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# ## Numberic Types and Operations

# %%
#name created not declared ahead of time. Variables and values
a = 3
b = 4

# %%
#Addition and subtraction with the output as a Tuple
a+1, a-1
# Out:
# (4, 2)

# %%
#Multiplication, division (float), power, modulus
a*2,a/3,a**3,a%2
# Out:
# (6, 1.0, 27, 1)

# %%
#mixed type conversions. One of the operators was a float so the results are now float
2 + 4.0, 2.0 ** b
# Out:
# (6.0, 16.0)

# %%
type(2)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
#calling an undefined object
c*2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-d6ccebdae9b2> in <module>()
#       1 #calling an undefined object
# ----> 2 c*2
#
# NameError: name 'c' is not defined

# %%
b/2+a
# Out:
# 5.0

# %%
b/(2+a)
# Out:
# 0.8

# %% [markdown]
# ## Numeric Display Formats

# %%
num = 1/3.0

# %%
print(num)
# Out:
# 0.3333333333333333

# %%
#String formatting Expression - scientific notation
'%e' %num
# Out:
# '3.333333e-01'

# %%
#ALternative floating point format
'%.2f' %num
# Out:
# '0.33'

# %%
'{:.6f'}.format
# Out:
#   File "<ipython-input-36-5cbe8b1817a0>", line 1
#     '{:.6f'}.format
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Comparisons: Normal and Chained
# Normal comparisons compare relative magnitudes their operands and returns a certain method or results.

# %%
2 > 1
# Out:
# True

# %%
#mixed type 
2.0 > 1
# Out:
# True

# %%
2.0 == 2.0
# Out:
# True

# %%
# Will be false because each value is a different type
2.0 != 2
# Out:
# False

# %%
2.0 == 2
# Out:
# True

# %%
# is is different than == 
2.0 is 2
# Out:
# False

# %%
X = 2
Y =4
Z =6

# %%
X<Y<Z
# Out:
# True

# %%
X < Y and Y<Z
# Out:
# True

# %%
X<Y and Y>Z
# Out:
# False

# %%
X < Y >Z
# Out:
# False

# %%
# This will be false because of the floating point. Need to massage before comparing
1.1 + 2.2 == 3.3
# Out:
# False

# %%
1.1 +2.2
# Out:
# 3.3000000000000003

# %%
int(1.1+2.2) ==int(3.3)
# Out:
# True

# %% [markdown]
# ## Bitwise Operations
# Python supports operators that treat integers as strings to binary bits. This can come in handy if your Python code must deal with things like network pakcets, serial ports, or packed binary data produced by a C program.

# %%
# 1 decimal is 0001 in bits
x = 1

# %%
#shift left two bits 
x << 2
# Out:
# 4

# %%
# Bitwise OR
x | 2
# Out:
# 3

# %%
#bitwise AND
x & 1
# Out:
# 1

# %%
3 & 5
# Out:
# 1

# %%
bin(4)
# Out:
# '0b100'

# %%
type(bin(4))
# Out:
# str

# %%
X = 0b0001
x
# Out:
# 1

# %%
x << 2
# Out:
# 4

# %%
bin(x | 0b010)
# Out:
# '0b11'

# %% [markdown]
# You can euse bit_leth method to query the umber of bits required to represent a number's value in binary

# %%
X = 8
bin(X), X.bit_length(),len(bin(X)) - 2
# Out:
# ('0b1000', 4, 4)

# %%
import math

# %%
#COMMON constants
math.pi, math.e
# Out:
# (3.141592653589793, 2.718281828459045)

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'hypot',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'pi',
#  'pow',
#  'radians',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'trunc']

# %%
math.sqrt(144),math.sqrt(2)
# Out:
# (12.0, 1.4142135623730951)

# %%
#Exponents
pow(2,4), 2** 4, 2.0**4.0
# Out:
# (16, 16, 16.0)

# %%
# Absolute value and summation, summation needs a list or tuple
abs(-42.0), sum((1,2,3,4))
# Out:
# (42.0, 10)

# %%
#min and max. min/max can just be values separated by commas
min(1,3,0), max(4,54,6)
# Out:
# (0, 54)

# %%
#next lowest integer
math.floor(2.5657), math.floor(-3.2334)
# Out:
# (2, -4)

# %%
math.trunc(2.2343), math.trunc(-3.32)
# Out:
# (2, -3)

# %%
#ROUNDING
round(2.32), round (4.92), round (2.321,2)
# Out:
# (2, 5, 2.32)

# %%
import math

# %%
#module
math.sqrt(144)
# Out:
# 12.0

# %%
#Expression
144 ** 0.5
# Out:
# 12.0

# %%
# Built in
pow(144,.5)
# Out:
# 12.0

# %%
import time

# %%
start_time = time.time()
[math.sqrt(144) for i in range (10000)]

end_time = time.time()
print("Elapsed time to run math.sqrt(144) was: ",
     end_time - start_time, "seconds")
# Out:
# Elapsed time to run math.sqrt(144) was:  0.007947206497192383 seconds

# %%
start_time = time.time()
[pow(144,.5) for i in range (10000)]

end_time = time.time()
print("Elapsed time to run math.sqrt(144) was: ",
     end_time - start_time, "seconds")
# Out:
# Elapsed time to run math.sqrt(144) was:  0.008079767227172852 seconds

# %%
start_time = time.time()
[144**.5 for i in range (10000)]

end_time = time.time()
print("Elapsed time to run math.sqrt(144) was: ",
     end_time - start_time, "seconds")
# Out:
# Elapsed time to run math.sqrt(144) was:  0.0004420280456542969 seconds

# %%
import random

# %%
random.random()
# Out:
# 0.622288042739101

# %%
random.random()
# Out:
# 0.0689017950191918

# %%
random.seed(100)

# %%
random.random()
# Out:
# 0.1456692551041303

# %%
random.seed(100)

# %%
random.random()
# Out:
# 0.1456692551041303

# %%
random.random()
# Out:
# 0.45492700451402135

# %%
random.seed(100)

# %%
random.random()
# Out:
# 0.1456692551041303

# %% [markdown]
# random.random()

# %%
random.choice(['life of brian','holy grail'])
# Out:
# 'life of brian'

# %%
random.choice(['life of brian','holy grail'])
# Out:
# 'holy grail'

# %%
random.choice(('life of brian','holy grail'))
# Out:
# 'holy grail'

# %%
suits = ['hearts', 'clubs', 'diamonds', 'spades']
random.shuffle(suits)

# %%
suits
# Out:
# ['clubs', 'hearts', 'diamonds', 'spades']

# %%
suits = ('hearts', 'clubs', 'diamonds', 'spades')
random.shuffle(suits)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-f27f2e6d574c> in <module>()
#       1 suits = ('hearts', 'clubs', 'diamonds', 'spades')
# ----> 2 random.shuffle(suits)
#
# ~/.virtualenvs/env1/lib/python3.4/random.py in shuffle(self, x, random)
#     270                 # pick an element in x[:i+1] with which to exchange x[i]
#     271                 j = randbelow(i+1)
# --> 272                 x[i], x[j] = x[j], x[i]
#     273         else:
#     274             _int = int
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Sets - an **unordered** collction of **unique** and **immutable** objects that supports operations corresponding to mathematical set theory.

# %%
# Built-in call (all))
set([1,2,3,4])
# Out:
# {1, 2, 3, 4}
